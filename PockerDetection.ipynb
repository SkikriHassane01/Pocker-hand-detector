# %% [markdown]
# ## Check for GPU

# %%
# first we will make sure that we have acces to GPU.

# !nvidia-smi
# Out:
# Tue Sep 17 22:11:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# **Great! we have acess to GPU `Tesla T4` with 1536Mib**

# %%
import os
HOME = os.getcwd() # get current working directory
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8 package

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# ## Download the dataset
#
# the link is [here](https://universe.roboflow.com/kuper/card-detection-zk7wu-gzidp)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="place here you api key")
project = rf.workspace("kuper").project("card-detection-zk7wu-gzidp")
version = project.version(1)
dataset = version.download("yolov8")

# %% [markdown]
# ## Training the Model

# %%
! yolo task=detect mode=train model=yolov8s.pt data=/content/Card-Detection-1/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
